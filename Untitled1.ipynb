# %%
auth_token = "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"

# %%
# Install necessary packages
# !pip install customtkinter torch diffusers pillow

# %%
import torch
from diffusers import StableDiffusionPipeline
from PIL import Image
import IPython.display as display

# Define your Hugging Face auth token
auth_token = "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"

# Load the model and pipeline with float32 for CPU
modelid = "CompVis/stable-diffusion-v1-4"
pipe = StableDiffusionPipeline.from_pretrained(modelid, torch_dtype=torch.float32, use_auth_token=auth_token)
pipe.to("cpu")  # Explicitly use CPU

# Function to generate and display an image
def generate(prompt):
    image = pipe(prompt, guidance_scale=8.5).images[0]

    # Save and display the generated image
    image.save('generatedimage.png')
    display.display(Image.open('generatedimage.png'))

# Example prompt
prompt = "zombie"
generate(prompt)
# Out:
# Keyword arguments {'use_auth_token': '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'} are not expected by StableDiffusionPipeline and will be ignored.
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
import torch
from diffusers import StableDiffusionPipeline
from PIL import Image
import IPython.display as display
from google.colab import files

# Define your Hugging Face auth token
auth_token = "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"

# Load the model and pipeline with float32 for CPU
modelid = "CompVis/stable-diffusion-v1-4"
pipe = StableDiffusionPipeline.from_pretrained(modelid, torch_dtype=torch.float32, use_auth_token=auth_token)
pipe.to("cpu")  # Explicitly use CPU

# Function to generate, display, and download an image
def generate(prompt):
    image = pipe(prompt, guidance_scale=8.5).images[0]

    # Save and display the generated image
    image.save('generatedimage.png')
    display.display(Image.open('generatedimage.png'))

    # Download the image
    files.download('generatedimage.png')

# Example prompt
prompt = "mountains with valcanos"
generate(prompt)
# Out:
# Keyword arguments {'use_auth_token': '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'} are not expected by StableDiffusionPipeline and will be ignored.
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>
